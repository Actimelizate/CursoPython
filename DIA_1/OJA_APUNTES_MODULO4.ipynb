# %%
#VARIABLES
# CREARLAS
n = 2
n
# Out:
# 2

# %%
print(n)
deci =  2.5
deci
# Out:
# 2
# 2.5

# %%
#LISTA
lista = ['Soy', 'el', 'numero', 1, True]
lista
print(lista)
lista[4]
# Out:
# ['Soy', 'el', 'numero', 1, True]
# True
