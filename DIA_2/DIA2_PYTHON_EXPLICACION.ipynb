# %% [markdown]
# Hola, esto es texto

# %%
# VARIABLES
# CREAR 
# nombre_variable = valor
numero = 2
numero_con_decimales = 2.5
verdadero = True
false = False
texto = "Hola"

# USAR
print(numero)
print(numero_con_decimales)
# Out:
# 2
# 2.5

# %%
# ESTRUCTURAS DE DATOS 
# LISTAS
# CREAR
lista = [1,2,3,4,"Hola",True]
# USAR
lista[-2]
# Out:
# 'Hola'

# %%
# OPERADORES ARITMETICOS
6 + 5
6 - 5
6 * 5
print(9 / 5) 
9 // 5
10 % 5
6 ** 8

# %%
# OPERADORES DE COMPARACIÓN
6 > 6
6 >= 6
6 < 5
"3" == 3
3 != 3
# Out:
# False

# %%
# 1º Parentesis
# 2º ** y raices cuadradas
# 3º * y /
# 4º + y -

# %%
"Hola" + "mundo"
# Out:
# 'Holamundo'

# %%
[1,6,3] + [4,5,2]
# Out:
# [1, 6, 3, 4, 5, 2]

# %%
lista = [1,2,3]
lista2 = [6,5]
lista.append("Hola")
lista.append("23")
print(lista)
# Out:
# [1, 2, 3, 'Hola', '23']

# %%
lista = [1,2,3]
lista.insert(0,"Hola")
lista
# Out:
# ['Hola', 1, 2, 3]

# %%
3.333 *3
# Out:
# 9.999

# %%
6 // 2
# Out:
# 3

# %%
str1 = """Me gusta Python"""
lsita= ["Me","gusta","Python"]
str1[3]
# Out:
# 'g'

# %%
nuestra_velocidad = 119
maxima_legal = 120

if nuestra_velocidad <= maxima_legal:
    print("Todo OK")
if nuestra_velocidad > maxima_legal:
    print("Multita")
# Out:
# Todo OK

# %%
nuestra_velocidad = 121
maxima_legal = 120

if nuestra_velocidad <= maxima_legal:
    print("Todo OK")
else:
    print("Multita")
# Out:
# Multita

# %%
nuestra_velocidad = 120
maxima_legal = 120

if nuestra_velocidad < maxima_legal:
    print("Todo OK")
elif nuestra_velocidad == maxima_legal:
    print("Tas al limite, para")
else:
    print("Multita")

if "Hola" > "Hol":
    print("Cierto")
# Out:
# Tas al limite, para
# Cierto
